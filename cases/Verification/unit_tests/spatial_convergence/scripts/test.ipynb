# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data = np.load("../outputs/convergence_results.npz")

# %%
dx, dy, l2, linf, res, rmse = data["dx"], data["dy"], data["l2_rel"], data["linf_rel"], data["resolution"], data["rmse"]

# %%
dx, l2, linf, res, rmse
# Out:
# (array([2.  , 1.  , 0.5 , 0.25]),
#  array([0.04211044, 0.02433902, 0.02154299, 0.02042405]),
#  array([1.5030365 , 1.2677629 , 1.55806458, 2.        ]),
#  array([ 128.,  256.,  512., 1024.]),
#  array([0.04211047, 0.02433904, 0.02154316, 0.02042461]))

# %%
# Reference curve
l2_ref = .05 * (dx) ** 2

# %%
plt.plot(dx, l2, 'o')
# plt.plot(dx, l2_ref, '--', label="Reference (2nd order)")
plt.xscale("log", base=2)
plt.yscale("log")
plt.xlabel("dx")
plt.ylabel("L2 error")
plt.title("Spatial Convergence")
plt.grid(True, which="both", ls="--")
plt.show()
